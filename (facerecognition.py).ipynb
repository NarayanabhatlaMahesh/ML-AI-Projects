# %%
pip install .
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Directory '.' is not installable. Neither 'setup.py' nor 'pyproject.toml' found.

# %%
pip install configparser
# Out:
# Requirement already satisfied: configparser in c:\users\numam\anaconda3\lib\site-packages (5.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from backports import configparser

# %%
pip install audio
# Out:
# Collecting audio
#   Using cached audio-1.5.0.tar.gz (2.1 kB)
# Collecting audio.bitstream
#   Using cached audio.bitstream-2.5.4.tar.gz (1.2 kB)
# Collecting audio.coders
#   Using cached audio.coders-4.0.2.tar.gz (682 kB)
#   Using cached audio.coders-4.0.1.tar.gz (682 kB)
#   Using cached audio.coders-4.0.0.tar.gz (682 kB)
#   Using cached audio.coders-3.1.0.tar.gz (681 kB)
#   Using cached audio.coders-3.0.0.tar.gz (683 kB)
#   Using cached audio.coders-2.0.1.tar.gz (539 kB)
#   Using cached audio.coders-2.0.0.tar.gz (538 kB)
#   Using cached audio.coders-1.0.1.tar.gz (538 kB)
#   Using cached audio.coders-1.0.0.tar.gz (538 kB)
# Collecting audio
#   Using cached audio-1.4.0.tar.gz (2.0 kB)
#   Using cached audio-1.3.0.tar.gz (1.1 kB)
#   Using cached audio-1.2.1.tar.gz (1.0 kB)
#   Using cached audio-1.1.0.tar.gz (1.0 kB)
#   Using cached audio-1.tar.gz (1.0 kB)
# Collecting audio.frames
#   Using cached audio.frames-2.3.1.tar.gz (535 kB)
#   Using cached audio.frames-2.3.0.tar.gz (535 kB)
#   Using cached audio.frames-2.1.tar.gz (536 kB)
#   Using cached audio.frames-2.0.4.tar.gz (535 kB)
#   Using cached audio.frames-2.0.3.tar.gz (535 kB)
#   Using cached audio.frames-2.0.2.tar.gz (535 kB)
#   Using cached audio.frames-2.0.1.tar.gz (3.3 kB)
#   Using cached audio.frames-2.0.0.tar.gz (535 kB)
#   Using cached audio.frames-1.0.2.tar.gz (773 kB)
#   Using cached audio.frames-1.0.tar.gz (773 kB)
#   Using cached audio.frames-0.1.tar.gz (536 kB)
# Collecting audio
#   Using cached audio-0.0.0.tar.gz (1.0 kB)
#
# The conflict is caused by:
#     audio 1.5.0 depends on audio.coders
#     audio 1.4.0 depends on audio.coders
#     audio 1.3.0 depends on audio.coders
#     audio 1.2.1 depends on audio.coders
#     audio 1.1.0 depends on audio.coding
#     audio 1 depends on audio.frames
#     audio 0.0.0 depends on audio.frames
#
# To fix this you could try to:
# 1. loosen the range of package versions you've specified
# 2. remove package versions to allow pip attempt to solve the dependency conflict
#
# Note: you may need to restart the kernel to use updated packages.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\numam\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\numam\\AppData\\Local\\Temp\\pip-install-bsfwoqpj\\audio-coders_954a3042aa1a45e78d1a5dab8f1f64f1\\setup.py'"'"'; __file__='"'"'C:\\Users\\numam\\AppData\\Local\\Temp\\pip-install-bsfwoqpj\\audio-coders_954a3042aa1a45e78d1a5dab8f1f64f1\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\numam\AppData\Local\Temp\pip-pip-egg-info-khqnm4g1'
#          cwd: C:\Users\numam\AppData\Local\Temp\pip-install-bsfwoqpj\audio-coders_954a3042aa1a45e78d1a5dab8f1f64f1\
#     Complete output (5 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\numam\AppData\Local\Temp\pip-install-bsfwoqpj\audio-coders_954a3042aa1a45e78d1a5dab8f1f64f1\setup.py", line 5, in <module>
#         import ConfigParser
#     ModuleNotFoundError: No module named 'ConfigParser'
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/4a/8d/d4fe457f6587005e8a4bd4597a12ceb4033e7557dc551b252451c6886967/audio.coders-4.0.2.tar.gz#sha256=7f7692fdc0aaecf2fe0441f31ada44caa32662ef4d8e071d6d131db7291d03fb (from https://pypi.org/simple/audio-coders/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\numam\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\numam\\AppData\\Local\\Temp\\pip-install-bsfwoqpj\\audio-coders_91ff51edecd84aa7811b40c26bd504ab\\setup.py'"'"'; __file__='"'"'C:\\Users\\numam\\AppData\\Local\\Temp\\pip-install-bsfwoqpj\\audio-coders_91ff51edecd84aa7811b40c26bd504ab\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\numam\AppData\Local\Temp\pip-pip-egg-info-7jprx0np'
#          cwd: C:\Users\numam\AppData\Local\Temp\pip-install-bsfwoqpj\audio-coders
\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\numam\AppData\Local\Temp\pip-pip-egg-info-u924muen'
#          cwd: C:\Users\numam\AppData\Local\Temp\pip-install-bsfwoqpj\audio-frames_90ee8caec2384163a2f5c263018c6956\
#     Complete output (5 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\numam\AppData\Local\Temp\pip-install-bsfwoqpj\audio-frames_90ee8caec2384163a2f5c263018c6956\setup.py", line 5, in <module>
#         import ConfigParser
#     ModuleNotFoundError: No module named 'ConfigParser'
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/ef/66/7166967772d068af6f85c63611c3dfd482fdadb3d69ef3d49a1e7c5ab2ab/audio.frames-0.1.tar.gz#sha256=4887830580c591fbbed42105c474d79804a12c016509ab0dad581bef9faf77c2 (from https://pypi.org/simple/audio-frames/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
# ERROR: Cannot install audio==0.0.0, audio==1, audio==1.1.0, audio==1.2.1, audio==1.3.0, audio==1.4.0 and audio==1.5.0 because these package versions have conflicting dependencies.
# ERROR: ResolutionImpossible: for help visit https://pip.pypa.io/en/latest/user_guide/#fixing-conflicting-dependencies

# %%
#################################### 
# IoT 2-Factor-Auth Door Lock (Facial + Voice Recognition)
# Kevin Leung @KSLHacks (Git: KSLHacks)
# James Earle @ItsJamesIRL (Git: JamesEarle)
# 9/12/2016

########### Python 2.7 #############
#!/usr/bin/python
# send_text option feature.. already implemented
# import send_text as st
import audio as a
import faceRecognition as f
import RPi.GPIO as GPIO
import os
import time

GPIO.setmode(GPIO.BCM)
GPIO.setwarnings(False)

GPIO.setup(23, GPIO.IN, pull_up_down=GPIO.PUD_UP)
GPIO.setup(18, GPIO.OUT) # face green
GPIO.setup(22, GPIO.OUT) # face red
GPIO.setup(17, GPIO.OUT) # voice green
GPIO.setup(27, GPIO.OUT) # voice red

# Flash all LEDs - Testing purposes + Signal Hardware/Script is running
GPIO.output(18, GPIO.LOW)
GPIO.output(22, GPIO.LOW)
GPIO.output(17, GPIO.LOW)
GPIO.output(27, GPIO.LOW)
time.sleep(0.5)
GPIO.output(18, GPIO.HIGH)
GPIO.output(22, GPIO.HIGH)
GPIO.output(17, GPIO.HIGH)
GPIO.output(27, GPIO.HIGH)
time.sleep(0.5)
GPIO.output(18, GPIO.LOW)
GPIO.output(22, GPIO.LOW)
GPIO.output(17, GPIO.LOW)
GPIO.output(27, GPIO.LOW)
time.sleep(0.5)
GPIO.output(18, GPIO.HIGH)
GPIO.output(22, GPIO.HIGH)
GPIO.output(17, GPIO.HIGH)
GPIO.output(27, GPIO.HIGH)
time.sleep(0.5)
GPIO.output(18, GPIO.LOW)
GPIO.output(22, GPIO.LOW)
GPIO.output(17, GPIO.LOW)
GPIO.output(27, GPIO.LOW)

# Face green
GPIO.output(18, GPIO.HIGH)
time.sleep(0.5)
GPIO.output(18, GPIO.LOW)

# Face red
GPIO.output(22, GPIO.HIGH)
time.sleep(0.5)
GPIO.output(22, GPIO.LOW)

# Voice green
GPIO.output(17, GPIO.HIGH)
time.sleep(0.5)
GPIO.output(17, GPIO.LOW)

# Voice red
GPIO.output(27, GPIO.HIGH)
time.sleep(0.5)
GPIO.output(27, GPIO.LOW)

old_input = GPIO.input(23)

print ("WAITING FOR BUTTON PRESS")
try:
    while True:
        new_input = GPIO.input(23)

        # Check for state change (button press)
        if(new_input != old_input):
            print(">>> BUTTON PRESS <<<")

	        # flash both face green and red to signify picture in progress
            print("Taking Picture..")
            GPIO.output(18, GPIO.HIGH)
            GPIO.output(22, GPIO.HIGH)

            # Take a photo using the Raspberry Pi camera
            os.system("raspistill -o output.jpg -q 40")

            # turn off face green and red to process
            print("Taking Picture - DONE")
            GPIO.output(18, GPIO.LOW)
            GPIO.output(22, GPIO.LOW)
            
            # Use the photo we just took and verify with API
            print("Verifying face...")
            if(f.faceVerify()):
                print("Success - Face!")
                # Face is a success - signify by lighting green face
                GPIO.output(18, GPIO.HIGH)
                time.sleep(1)

                # Now test voice
                # flash both voice green and red to signify voice in progress
                print("Taking Voice Sample..")
                GPIO.output(17, GPIO.HIGH)
                GPIO.output(27, GPIO.HIGH)
	
                # Take a voice recording using the USB Device microphone for 10seconds
                os.system("arecord -D plughw:1 -d 5 -f S16 -r 16000 voice_record.wav")		

                # Turn off voice green and red to process
                print("Taking Voice Sample - DONE")
                GPIO.output(17, GPIO.LOW)
                GPIO.output(27, GPIO.LOW)

                # Use voice recording and verify with API
                if(a.voiceVerify()):
                    print("Success - Voice!")
                    GPIO.output(17, GPIO.HIGH)
                    break
                else:
                    print("Failure - Voice!")
                    GPIO.output(27, GPIO.HIGH)
                    break
            else:
                # Failed to verify, send text and return
                print("Failure - Face!")
                GPIO.output(22, GPIO.HIGH)
                time.sleep(3)
                # texting functionality commented out for this demo - refer to implementation for details
                #st.run()
                break
            time.sleep(0.2)
finally:

    # hold this finished position until button is pressed again to end the program
    old_input = GPIO.input(23)
    while True:
        new_input = GPIO.input(23)

        # Check for state change (button press)
        if(new_input != old_input):
            break
        else:
            continue
	
    # Turn of LEDs
    GPIO.output(18, GPIO.LOW)
    GPIO.output(22, GPIO.LOW)
    GPIO.output(17, GPIO.LOW)
    GPIO.output(27, GPIO.LOW)
    time.sleep(0.5)
    GPIO.output(18, GPIO.HIGH)
    GPIO.output(22, GPIO.HIGH)
    GPIO.output(17, GPIO.HIGH)
    GPIO.output(27, GPIO.HIGH)
    time.sleep(0.5)
    GPIO.output(18, GPIO.LOW)
    GPIO.output(22, GPIO.LOW)
    GPIO.output(17, GPIO.LOW)
    GPIO.output(27, GPIO.LOW)
    time.sleep(0.5)
    GPIO.output(18, GPIO.HIGH)
    GPIO.output(22, GPIO.HIGH)
    GPIO.output(17, GPIO.HIGH)
    GPIO.output(27, GPIO.HIGH)
    time.sleep(0.5)
    GPIO.output(18, GPIO.LOW)
    GPIO.output(22, GPIO.LOW)
    GPIO.output(17, GPIO.LOW)
    GPIO.output(27, GPIO.LOW)

    print("Finished")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11400/2000251937.py in <module>
#       9 # send_text option feature.. already implemented
#      10 # import send_text as st
# ---> 11 import audio as a
#      12 import faceRecognition as f
#      13 import RPi.GPIO as GPIO
#
# ModuleNotFoundError: No module named 'audio'
