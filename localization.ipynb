# %%
###Reference###
#https://www.analyticsvidhya.com/blog/2019/04/introduction-image-segmentation-techniques-python/
from skimage.color import rgb2gray
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy import ndimage

# %%
import os
pwd=os.getcwd()
chdir=pwd+'\\deepglobe'
os.chdir(chdir)

# %%
#Set Parameters
im_width = 256
im_height = 256

# %%
files=os.listdir()
print(files)
# Out:
# ['class_dict.csv', 'metadata.csv', 'test', 'train', 'valid']

# %%
import pandas as pd
ClassDict=pd.read_csv(files[0])
ClassDict
# Out:
#          name    r    g    b
# 0        road  255  255  255
# 1  background    0    0    0

# %%
MetaData=pd.read_csv(files[1])
MetaData
# Out:
#       image_id  split        sat_image_path              mask_path
# 0       100034  train  train/100034_sat.jpg  train/100034_mask.png
# 1       100081  train  train/100081_sat.jpg  train/100081_mask.png
# 2       100129  train  train/100129_sat.jpg  train/100129_mask.png
# 3       100703  train  train/100703_sat.jpg  train/100703_mask.png
# 4       100712  train  train/100712_sat.jpg  train/100712_mask.png
# ...        ...    ...                   ...                    ...
# 8565    998829   test   test/998829_sat.jpg                    NaN
# 8566    998928   test   test/998928_sat.jpg                    NaN
# 8567    999518   test   test/999518_sat.jpg                    NaN
# 8568    999651   test   test/999651_sat.jpg                    NaN
# 8569    999703   test   test/999703_sat.jpg                    NaN
#
# [8570 rows x 4 columns]

# %%
MD=MetaData
MD=MD.dropna()

# %%
MetaData=MD

# %%
MetaData
# Out:
#       image_id  split        sat_image_path              mask_path
# 0       100034  train  train/100034_sat.jpg  train/100034_mask.png
# 1       100081  train  train/100081_sat.jpg  train/100081_mask.png
# 2       100129  train  train/100129_sat.jpg  train/100129_mask.png
# 3       100703  train  train/100703_sat.jpg  train/100703_mask.png
# 4       100712  train  train/100712_sat.jpg  train/100712_mask.png
# ...        ...    ...                   ...                    ...
# 6221    999431  train  train/999431_sat.jpg  train/999431_mask.png
# 6222    999531  train  train/999531_sat.jpg  train/999531_mask.png
# 6223    999667  train  train/999667_sat.jpg  train/999667_mask.png
# 6224    999764  train  train/999764_sat.jpg  train/999764_mask.png
# 6225     99995  train   train/99995_sat.jpg   train/99995_mask.png
#
# [6226 rows x 4 columns]

# %%
file=MetaData['sat_image_path']
pic = plt.imread(file[0])/255  # dividing by 255 to bring the pixel values between 0 and 1
print(pic.shape)
plt.imshow(pic)
# Out:
# (1024, 1024, 3)

# %%
pic_n = pic.reshape(pic.shape[0]*pic.shape[1], pic.shape[2])
pic_n.shape
# Out:
# (1048576, 3)

# %%
a=[]
b=[]
c=[]
for i,j,k in pic_n:
    a.append(i)
    b.append(j)
    c.append(k)
max(a)
# Out:
# 0.9764705882352941

# %%
# %matplotlib notebook
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
 
fig = plt.figure()
 
# syntax for 3-D projection
ax = plt.axes(projection ='3d')

ax.plot3D(a,b,c , 'green')
# Out:
# <img src="data:image/png;base64,..." width="389">

# %%
d=[]
val=[]
for i in a:
    d.append(i)
    d.append(0)
    d.append(0)
    val.append(d)
    d=[]
d=[]
for i in b:
    d.append(i)
    d.append(0)
    d.append(0)
    val.append(d)
    d=[]
d=[]
for i in c:
    d.append(i)
    d.append(0)
    d.append(0)
    val.append(d)
    d=[]

# %%
a=[]
b=[]
c=[]
for i,j,k in val:
    a.append(i)
    b.append(j)
    c.append(k)

# %%
# %matplotlib notebook
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
 
fig = plt.figure()
 
# syntax for 3-D projection
ax = plt.axes(projection ='3d')

ax.plot3D(a,b,c , 'green')
# Out:
# <img src="data:image/png;base64,..." width="387.77778805038105">

# %%
#bring back the clusters to their original shape,
#i.e. 3-dimensional image, and plot the results.
cluster_pic = pic2show.reshape(pic.shape[0], pic.shape[1], pic.shape[2])
plt.imshow(cluster_pic)
