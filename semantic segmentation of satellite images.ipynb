# %%
import tensorflow as tf
tf.compat.v1.disable_eager_execution()

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('C:\\Users\\numam\\OneDrive\\Desktop\\Dataset'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\classes.json
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 1\images\image_part_001.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 1\images\image_part_002.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 1\images\image_part_003.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 1\images\image_part_004.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 1\images\image_part_005.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 1\images\image_part_006.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 1\images\image_part_007.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 1\images\image_part_008.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 1\images\image_part_009.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 1\masks\image_part_001.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 1\masks\image_part_002.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 1\masks\image_part_003.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 1\masks\image_part_004.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 1\masks\image_part_005.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 1\masks\image_part_006.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 1\masks\image_part_007.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 1\masks\image_part_008.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 1\masks\image_part_009.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 2\images\image_part_001.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 2\images\image_part_002.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 2\images\image_part_003.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 2\images\image_part_004.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 2\images\image_part_005.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 2\images\image_part_006.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 2\images\image_part_007.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 2\images\image_part_008.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 2\images\image_part_009.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 2\masks\image_part_001.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 2\masks\image_part_002.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 2\masks\image_part_003.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 2\masks\image_part_004.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 2\masks\image_part_005.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 2\masks\image_part_006.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 2\masks\image_part_007.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 2\masks\image_part_008.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 2\masks\image_part_009.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 3\images\image_part_001.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 3\images\image_part_002.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 3\images\image_part_003.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 3\images\image_part_004.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 3\images\image_part_005.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 3\images\image_part_006.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 3\images\image_part_007.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 3\images\image_part_008.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 3\images\image_part_009.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 3\masks\image_part_001.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 3\masks\image_part_002.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 3\masks\image_part_003.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 3\masks\image_part_004.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 3\masks\image_part_005.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 3\masks\image_part_006.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 3\masks\image_part_007.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 3\masks\image_part_008.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 3\masks\image_part_009.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 4\images\image_part_001.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 4\images\image_part_002.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 4\images\image_part_003.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 4\images\image_part_004.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 4\images\image_part_005.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 4\images\image_part_006.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 4\images\image_part_007.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 4\images\image_part_008.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 4\images\image_part_009.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 4\masks\image_part_001.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 4\masks\image_part_002.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 4\masks\image_part_003.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 4\masks\image_part_004.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 4\masks\image_part_005.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 4\masks\image_part_006.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 4\masks\image_part_007.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 4\masks\image_part_008.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 4\masks\image_part_009.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 5\images\image_part_001.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 5\images\image_part_002.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 5\images\image_part_003.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 5\images\image_part_004.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 5\images\image_part_005.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 5\images\image_part_006.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 5\images\image_part_007.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 5\images\image_part_008.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 5\images\image_part_009.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 5\masks\image_part_001.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 5\masks\image_part_002.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 5\masks\image_part_003.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 5\masks\image_part_004.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 5\masks\image_part_005.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 5\masks\image_part_006.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 5\masks\image_part_007.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 5\masks\image_part_008.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 5\masks\image_part_009.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 6\images\image_part_001.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 6\images\image_part_002.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 6\images\image_part_003.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 6\images\image_part_004.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 6\images\image_part_005.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 6\images\image_part_006.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 6\images\image_part_007.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 6\images\image_part_008.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 6\images\image_part_009.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 6\masks\image_part_001.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 6\masks\image_part_002.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 6\masks\image_part_003.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 6\masks\image_part_004.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 6\masks\image_part_005.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 6\masks\image_part_006.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 6\masks\image_part_007.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 6\masks\image_part_008.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 6\masks\image_part_009.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 7\images\image_part_001.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 7\images\image_part_002.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 7\images\image_part_003.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 7\images\image_part_004.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 7\images\image_part_005.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 7\images\image_part_006.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 7\images\image_part_007.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 7\images\image_part_008.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 7\images\image_part_009.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 7\masks\image_part_001.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 7\masks\image_part_002.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 7\masks\image_part_003.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 7\masks\image_part_004.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 7\masks\image_part_005.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 7\masks\image_part_006.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 7\masks\image_part_007.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 7\masks\image_part_008.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 7\masks\image_part_009.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 8\images\image_part_001.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 8\images\image_part_002.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 8\images\image_part_003.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 8\images\image_part_004.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 8\images\image_part_005.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 8\images\image_part_006.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 8\images\image_part_007.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 8\images\image_part_008.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 8\images\image_part_009.jpg
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 8\masks\image_part_001.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 8\masks\image_part_002.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 8\masks\image_part_003.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 8\masks\image_part_004.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 8\masks\image_part_005.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 8\masks\image_part_006.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 8\masks\image_part_007.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 8\masks\image_part_008.png
# C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 8\masks\image_part_009.png

# %%
# !pip install patchify
# !pip install segmentation-models
# Out:
# Requirement already satisfied: patchify in c:\users\numam\anaconda3\lib\site-packages (0.2.3)
# Requirement already satisfied: numpy<2,>=1 in c:\users\numam\anaconda3\lib\site-packages (from patchify) (1.21.5)
# Requirement already satisfied: segmentation-models in c:\users\numam\anaconda3\lib\site-packages (1.0.1)
# Requirement already satisfied: keras-applications<=1.0.8,>=1.0.7 in c:\users\numam\anaconda3\lib\site-packages (from segmentation-models) (1.0.8)
# Requirement already satisfied: efficientnet==1.0.0 in c:\users\numam\anaconda3\lib\site-packages (from segmentation-models) (1.0.0)
# Requirement already satisfied: image-classifiers==1.0.0 in c:\users\numam\anaconda3\lib\site-packages (from segmentation-models) (1.0.0)
# Requirement already satisfied: scikit-image in c:\users\numam\anaconda3\lib\site-packages (from efficientnet==1.0.0->segmentation-models) (0.19.2)
# Requirement already satisfied: h5py in c:\users\numam\anaconda3\lib\site-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (3.7.0)
# Requirement already satisfied: numpy>=1.9.1 in c:\users\numam\anaconda3\lib\site-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (1.21.5)
# Requirement already satisfied: networkx>=2.2 in c:\users\numam\anaconda3\lib\site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2.8.4)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\numam\anaconda3\lib\site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.3.0)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in c:\users\numam\anaconda3\lib\site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (9.2.0)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\users\numam\anaconda3\lib\site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2021.7.2)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\numam\anaconda3\lib\site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.9.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\numam\anaconda3\lib\site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (21.3)
# Requirement already satisfied: imageio>=2.4.1 in c:\users\numam\anaconda3\lib\site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2.19.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\numam\anaconda3\lib\site-packages (from packaging>=20.0->scikit-image->efficientnet==1.0.0->segmentation-models) (3.0.9)

# %%
import tensorflow as tf
tf.debugging.set_log_device_placement(True)

# %%
tf.test.is_gpu_available(
    cuda_only=False, min_cuda_compute_capability=None
)
# Out:
# WARNING:tensorflow:From C:\Users\numam\AppData\Local\Temp\ipykernel_2988\501681495.py:1: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# True

# %%
import os 
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import cv2
import numpy as np
import glob as gb
from matplotlib import pyplot as plt
from patchify import patchify
from PIL import Image
import segmentation_models as sm
from tensorflow.keras.metrics import MeanIoU

from sklearn.preprocessing import MinMaxScaler, StandardScaler
scaler = MinMaxScaler()
# Out:
# Segmentation Models: using `keras` framework.

# %%
import tensorflow as tf
gpu_devices = tf.config.experimental.list_physical_devices('GPU') 

for device in gpu_devices:
    tf.config.experimental.set_memory_growth(device, True)

# %%
root_directory = 'C:\\Users\\numam\\OneDrive\\Desktop\\Dataset'

patch_size = 256

# %%
image_dataset = []  
for path, subdirs, files in os.walk(root_directory):
    #print(path)  
    dirname = path.split(os.path.sep)[-1]
    if dirname == 'images':   #Find all 'images' directories
        images = os.listdir(path)  #List of all image names in this subdirectory
        for i, image_name in enumerate(images):  
            if image_name.endswith(".jpg"):   #Only read jpg images...
               
                image = cv2.imread(path+"/"+image_name, 1)  #Read each image as BGR
                SIZE_X = (image.shape[1]//patch_size)*patch_size #Nearest size divisible by our patch size
                SIZE_Y = (image.shape[0]//patch_size)*patch_size #Nearest size divisible by our patch size
                image = Image.fromarray(image)
                image = image.crop((0 ,0, SIZE_X, SIZE_Y))  #Crop from top left corner
                #image = image.resize((SIZE_X, SIZE_Y))  #Try not to resize for semantic segmentation
                image = np.array(image)             
       
                #Extract patches from each image
                print("Now patchifying image:", path+"/"+image_name)
                patches_img = patchify(image, (patch_size, patch_size, 3), step=patch_size)  #Step=256 for 256 patches means no overlap
        
                for i in range(patches_img.shape[0]):
                    for j in range(patches_img.shape[1]):
                        
                        single_patch_img = patches_img[i,j,:,:]
                        
                        #Use minmaxscaler instead of just dividing by 255. 
                        single_patch_img = scaler.fit_transform(single_patch_img.reshape(-1, single_patch_img.shape[-1])).reshape(single_patch_img.shape)
                        
                        #single_patch_img = (single_patch_img.astype('float32')) / 255. 
                        single_patch_img = single_patch_img[0] #Drop the extra unecessary dimension that patchify adds.                               
                        image_dataset.append(single_patch_img)
# Out:
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 1\images/image_part_001.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 1\images/image_part_002.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 1\images/image_part_003.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 1\images/image_part_004.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 1\images/image_part_005.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 1\images/image_part_006.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 1\images/image_part_007.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 1\images/image_part_008.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 1\images/image_part_009.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 2\images/image_part_001.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 2\images/image_part_002.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 2\images/image_part_003.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 2\images/image_part_004.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 2\images/image_part_005.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 2\images/image_part_006.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 2\images/image_part_007.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 2\images/image_part_008.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 2\images/image_part_009.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 3\images/image_part_001.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 3\images/image_part_002.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 3\images/image_part_003.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 3\images/image_part_004.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 3\images/image_part_005.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 3\images/image_part_006.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 3\images/image_part_007.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 3\images/image_part_008.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 3\images/image_part_009.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 4\images/image_part_001.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 4\images/image_part_002.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 4\images/image_part_003.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 4\images/image_part_004.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 4\images/image_part_005.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 4\images/image_part_006.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 4\images/image_part_007.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 4\images/image_part_008.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 4\images/image_part_009.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 5\images/image_part_001.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 5\images/image_part_002.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 5\images/image_part_003.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 5\images/image_part_004.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 5\images/image_part_005.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 5\images/image_part_006.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 5\images/image_part_007.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 5\images/image_part_008.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 5\images/image_part_009.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 6\images/image_part_001.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 6\images/image_part_002.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 6\images/image_part_003.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 6\images/image_part_004.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 6\images/image_part_005.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 6\images/image_part_006.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 6\images/image_part_007.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 6\images/image_part_008.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 6\images/image_part_009.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 7\images/image_part_001.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 7\images/image_part_002.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 7\images/image_part_003.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 7\images/image_part_004.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 7\images/image_part_005.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 7\images/image_part_006.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 7\images/image_part_007.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 7\images/image_part_008.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 7\images/image_part_009.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 8\images/image_part_001.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 8\images/image_part_002.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 8\images/image_part_003.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 8\images/image_part_004.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 8\images/image_part_005.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 8\images/image_part_006.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 8\images/image_part_007.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 8\images/image_part_008.jpg
# Now patchifying image: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 8\images/image_part_009.jpg

# %%
mask_dataset = []  
for path, subdirs, files in os.walk(root_directory):
    #print(path)  
    dirname = path.split(os.path.sep)[-1]
    if dirname == 'masks':   #Find all 'images' directories
        masks = os.listdir(path)  #List of all image names in this subdirectory
        for i, mask_name in enumerate(masks):  
            if mask_name.endswith(".png"):   #Only read png images... (masks in this dataset)
               
                mask = cv2.imread(path+"/"+mask_name, 1)  #Read each image as Grey (or color but remember to map each color to an integer)
                mask = cv2.cvtColor(mask,cv2.COLOR_BGR2RGB)
                SIZE_X = (mask.shape[1]//patch_size)*patch_size #Nearest size divisible by our patch size
                SIZE_Y = (mask.shape[0]//patch_size)*patch_size #Nearest size divisible by our patch size
                mask = Image.fromarray(mask)
                mask = mask.crop((0 ,0, SIZE_X, SIZE_Y))  #Crop from top left corner
                #mask = mask.resize((SIZE_X, SIZE_Y))  #Try not to resize for semantic segmentation
                mask = np.array(mask)             
       
                #Extract patches from each image
                print("Now patchifying mask:", path+"/"+mask_name)
                patches_mask = patchify(mask, (patch_size, patch_size, 3), step=patch_size)  #Step=256 for 256 patches means no overlap
        
                for i in range(patches_mask.shape[0]):
                    for j in range(patches_mask.shape[1]):
                        
                        single_patch_mask = patches_mask[i,j,:,:]
                        #single_patch_img = (single_patch_img.astype('float32')) / 255. #No need to scale masks, but you can do it if you want
                        single_patch_mask = single_patch_mask[0] #Drop the extra unecessary dimension that patchify adds.                               
                        mask_dataset.append(single_patch_mask)
# Out:
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 1\masks/image_part_001.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 1\masks/image_part_002.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 1\masks/image_part_003.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 1\masks/image_part_004.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 1\masks/image_part_005.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 1\masks/image_part_006.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 1\masks/image_part_007.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 1\masks/image_part_008.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 1\masks/image_part_009.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 2\masks/image_part_001.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 2\masks/image_part_002.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 2\masks/image_part_003.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 2\masks/image_part_004.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 2\masks/image_part_005.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 2\masks/image_part_006.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 2\masks/image_part_007.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 2\masks/image_part_008.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 2\masks/image_part_009.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 3\masks/image_part_001.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 3\masks/image_part_002.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 3\masks/image_part_003.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 3\masks/image_part_004.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 3\masks/image_part_005.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 3\masks/image_part_006.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 3\masks/image_part_007.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 3\masks/image_part_008.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 3\masks/image_part_009.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 4\masks/image_part_001.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 4\masks/image_part_002.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 4\masks/image_part_003.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 4\masks/image_part_004.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 4\masks/image_part_005.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 4\masks/image_part_006.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 4\masks/image_part_007.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 4\masks/image_part_008.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 4\masks/image_part_009.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 5\masks/image_part_001.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 5\masks/image_part_002.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 5\masks/image_part_003.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 5\masks/image_part_004.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 5\masks/image_part_005.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 5\masks/image_part_006.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 5\masks/image_part_007.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 5\masks/image_part_008.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 5\masks/image_part_009.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 6\masks/image_part_001.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 6\masks/image_part_002.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 6\masks/image_part_003.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 6\masks/image_part_004.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 6\masks/image_part_005.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 6\masks/image_part_006.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 6\masks/image_part_007.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 6\masks/image_part_008.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 6\masks/image_part_009.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 7\masks/image_part_001.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 7\masks/image_part_002.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 7\masks/image_part_003.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 7\masks/image_part_004.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 7\masks/image_part_005.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 7\masks/image_part_006.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 7\masks/image_part_007.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 7\masks/image_part_008.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 7\masks/image_part_009.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 8\masks/image_part_001.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 8\masks/image_part_002.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 8\masks/image_part_003.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 8\masks/image_part_004.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 8\masks/image_part_005.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 8\masks/image_part_006.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 8\masks/image_part_007.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 8\masks/image_part_008.png
# Now patchifying mask: C:\Users\numam\OneDrive\Desktop\Dataset\Semantic segmentation dataset\Tile 8\masks/image_part_009.png

# %%
image_dataset = np.array(image_dataset)
print(image_dataset.shape)
mask_dataset =  np.array(mask_dataset)
print(mask_dataset.shape)
# Out:
# (1305, 256, 256, 3)
# (1305, 256, 256, 3)

# %%
import random
image_number = random.randint(0, len(image_dataset))
plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.imshow(np.reshape(image_dataset[image_number], (patch_size, patch_size, 3)))
plt.subplot(122)
plt.imshow(np.reshape(mask_dataset[image_number], (patch_size, patch_size, 3)))
plt.show()

# %%
Building = '#3C1098'.lstrip('#')
Building = np.array(tuple(int(Building[i:i+2], 16) for i in (0, 2, 4))) # 60, 16, 152

Land = '#8429F6'.lstrip('#')
Land = np.array(tuple(int(Land[i:i+2], 16) for i in (0, 2, 4))) #132, 41, 246

Road = '#6EC1E4'.lstrip('#') 
Road = np.array(tuple(int(Road[i:i+2], 16) for i in (0, 2, 4))) #110, 193, 228

Vegetation =  'FEDD3A'.lstrip('#') 
Vegetation = np.array(tuple(int(Vegetation[i:i+2], 16) for i in (0, 2, 4))) #254, 221, 58

Water = 'E2A929'.lstrip('#') 
Water = np.array(tuple(int(Water[i:i+2], 16) for i in (0, 2, 4))) #226, 169, 41

Unlabeled = '#9B9B9B'.lstrip('#') 
Unlabeled = np.array(tuple(int(Unlabeled[i:i+2], 16) for i in (0, 2, 4))) #155, 155, 155

# %%
label = single_patch_mask
label.shape
# Out:
# (256, 256, 3)

# %%
# Now replace RGB to integer values to be used as labels.
#Find pixels with combination of RGB for the above defined arrays...
#if matches then replace all values in that pixel with a specific integer
def rgb_to_2D_label(label):
    """
    Suply our labale masks as input in RGB format. 
    Replace pixels with specific RGB values ...
    """
    label_seg = np.zeros(label.shape,dtype=np.uint8)
    label_seg [np.all(label == Building,axis=-1)] = 0
    label_seg [np.all(label==Land,axis=-1)] = 1
    label_seg [np.all(label==Road,axis=-1)] = 2
    label_seg [np.all(label==Vegetation,axis=-1)] = 3
    label_seg [np.all(label==Water,axis=-1)] = 4
    label_seg [np.all(label==Unlabeled,axis=-1)] = 5
    
    label_seg = label_seg[:,:,0]  #Just take the first channel, no need for all 3 channels
    
    return label_seg

# %%
labels = []
for i in range(mask_dataset.shape[0]):
    label = rgb_to_2D_label(mask_dataset[i])
    labels.append(label)    

labels = np.array(labels)

# %%
labels.shape
# Out:
# (1305, 256, 256)

# %%
labels = np.expand_dims(labels, axis=3)

# %%
labels.shape
# Out:
# (1305, 256, 256, 1)

# %%
print("Unique labels in label dataset are: ", np.unique(labels))
# Out:
# Unique labels in label dataset are:  [0 1 2 3 4 5]

# %%
import random
import numpy as np
image_number
plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.imshow(image_dataset[image_number])
plt.subplot(122)
plt.imshow(labels[image_number][:,:,0])
plt.show()

# %%
n_classes = len(np.unique(labels))
from tensorflow.keras.utils import to_categorical
labels_cat = to_categorical(labels, num_classes=n_classes)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(image_dataset, labels_cat, test_size = 0.20, random_state = 42)

# %%
weights = [0.1666, 0.1666, 0.1666, 0.1666, 0.1666, 0.1666]
dice_loss = sm.losses.DiceLoss(class_weights=weights) 
focal_loss = sm.losses.CategoricalFocalLoss()
total_loss = dice_loss + (1 * focal_loss)

# %%
IMG_HEIGHT = X_train.shape[1]
IMG_WIDTH  = X_train.shape[2]
IMG_CHANNELS = X_train.shape[3]

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Conv2DTranspose, BatchNormalization, Dropout, Lambda
from tensorflow.keras import backend as K

def jacard_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) - intersection + 1.0)

# %%
def multi_unet_model(n_classes=4, IMG_HEIGHT=256, IMG_WIDTH=256, IMG_CHANNELS=1):
#Build the model
    inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
    #s = Lambda(lambda x: x / 255)(inputs)   #No need for this if we normalize our inputs beforehand
    s = inputs

    #Contraction path
    c1 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(s)
    c1 = Dropout(0.2)(c1)  # Original 0.1
    c1 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c1)
    p1 = MaxPooling2D((2, 2))(c1)
    
    c2 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p1)
    c2 = Dropout(0.2)(c2)  # Original 0.1
    c2 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c2)
    p2 = MaxPooling2D((2, 2))(c2)
     
    c3 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p2)
    c3 = Dropout(0.2)(c3)
    c3 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c3)
    p3 = MaxPooling2D((2, 2))(c3)
     
    c4 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p3)
    c4 = Dropout(0.2)(c4)
    c4 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c4)
    p4 = MaxPooling2D(pool_size=(2, 2))(c4)
     
    c5 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p4)
    c5 = Dropout(0.3)(c5)
    c5 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c5)
    
    #Expansive path 
    u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c5)
    u6 = concatenate([u6, c4])
    c6 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u6)
    c6 = Dropout(0.2)(c6)
    c6 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c6)
     
    u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c6)
    u7 = concatenate([u7, c3])
    c7 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u7)
    c7 = Dropout(0.2)(c7)
    c7 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c7)
     
    u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c7)
    u8 = concatenate([u8, c2])
    c8 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u8)
    c8 = Dropout(0.2)(c8)  # Original 0.1
    c8 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c8)
     
    u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(c8)
    u9 = concatenate([u9, c1], axis=3)
    c9 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u9)
    c9 = Dropout(0.2)(c9)  # Original 0.1
    c9 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c9)
     
    outputs = Conv2D(n_classes, (1, 1), activation='softmax')(c9)
     
    model = Model(inputs=[inputs], outputs=[outputs])
    return model

# %%
metrics=['accuracy', jacard_coef]

# %%
model= multi_unet_model(n_classes=n_classes, IMG_HEIGHT=IMG_HEIGHT, IMG_WIDTH=IMG_WIDTH,IMG_CHANNELS=IMG_CHANNELS)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 256, 256, 16  448         ['input_1[0][0]']
#                                 )
#
#  dropout (Dropout)              (None, 256, 256, 16  0           ['conv2d[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 256, 256, 16  2320        ['dropout[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 128, 128, 16  0           ['conv2d_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 128, 128, 32  4640        ['max_pooling2d[0][0]']
#                                 )
#
#  dropout_1 (Dropout)            (None, 128, 128, 32  0           ['conv2d_2[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 128, 128, 32  9248        ['dropout_1[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 32)  0           ['conv2d_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 64, 64, 64)   18496       ['max_pooling2d_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 64, 64, 64)   0           ['conv2d_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 64, 64, 64)   36928       ['dropout_2[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 64)  0           ['conv2d_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 128)  73856       ['max_pooling2d_2[0][0]']
#
#  dropout_3 (Dropout)            (None, 32, 32, 128)  0           ['conv2d_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 128)  147584      ['dropout_3[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 128)  0          ['conv2d_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 16, 16, 256)  295168      ['max_pooling2d_3[0][0]']
#
#  dropout_4 (Dropout)            (None, 16, 16, 256)  0           ['conv2d_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 16, 16, 256)  590080      ['dropout_4[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 32, 32, 128)  131200     ['conv2d_9[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 32, 32, 256)  0           ['conv2d_transpose[0][0]',
#                                                                   'conv2d_7[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 128)  295040      ['concatenate[0][0]']
#
#  dropout_5 (Dropout)            (None, 32, 32, 128)  0           ['conv2d_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 32, 32, 128)  147584      ['dropout_5[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 64, 64, 64)  32832       ['conv2d_11[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 64, 64, 128)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 64, 64, 64)   73792       ['concatenate_1[0][0]']
#
#  dropout_6 (Dropout)            (None, 64, 64, 64)   0           ['conv2d_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 64, 64, 64)   36928       ['dropout_6[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 128, 128, 32  8224       ['conv2d_13[0][0]']
#  spose)                         )
#
#  concatenate_2 (Concatenate)    (None, 128, 128, 64  0           ['conv2d_transpose_2[0][0]',
#                                 )                                 'conv2d_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 128, 128, 32  18464       ['concatenate_2[0][0]']
#                                 )
#
#  dropout_7 (Dropout)            (None, 128, 128, 32  0           ['conv2d_14[0][0]']
#                                 )
#
#  conv2d_15 (Conv2D)             (None, 128, 128, 32  9248        ['dropout_7[0][0]']
#                                 )
#
#  conv2d_transpose_3 (Conv2DTran  (None, 256, 256, 16  2064       ['conv2d_15[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 256, 256, 32  0           ['conv2d_transpose_3[0][0]',
#                                 )                                 'conv2d_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 256, 256, 16  4624        ['concatenate_3[0][0]']
#                                 )
#
#  dropout_8 (Dropout)            (None, 256, 256, 16  0           ['conv2d_16[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 256, 256, 16  2320        ['dropout_8[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 256, 256, 6)  102         ['conv2d_17[0][0]']
#
# ==================================================================================================
# Total params: 1,941,190
# Trainable params: 1,941,190
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(optimizer='adam', loss=total_loss, metrics=metrics)
#model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=metrics)

# %%
from tensorflow.keras.callbacks import EarlyStopping ,ReduceLROnPlateau ,ModelCheckpoint
EarlyStop=EarlyStopping(patience=10,restore_best_weights=True)
Reduce_LR=ReduceLROnPlateau(monitor='val_accuracy',verbose=2,factor=0.5,min_lr=0.00001)
model_check=ModelCheckpoint('satellite_features.h5',monitor='val_loss',verbose=1,save_best_only=True)
callback=[EarlyStop , Reduce_LR,model_check]

# %%
history1 = model.fit(X_train, y_train, 
                    batch_size = 8, 
                    verbose=1, 
                    epochs=15, 
                    validation_data=(X_test, y_test), 
                    shuffle=False)
# Out:
# Train on 1044 samples, validate on 261 samples
# Epoch 1/15
# 1044/1044 [==============================] - 35s 34ms/sample - loss: 0.9073 - accuracy: 0.8560 - jacard_coef: 0.7046 - val_loss: 0.9185 - val_accuracy: 0.8321 - val_jacard_coef: 0.6792
# Epoch 2/15
# 1044/1044 [==============================] - 35s 34ms/sample - loss: 0.9078 - accuracy: 0.8541 - jacard_coef: 0.7022 - val_loss: 0.9173 - val_accuracy: 0.8351 - val_jacard_coef: 0.6826
# Epoch 3/15
# 1044/1044 [==============================] - 35s 33ms/sample - loss: 0.9064 - accuracy: 0.8571 - jacard_coef: 0.7085 - val_loss: 0.9212 - val_accuracy: 0.8291 - val_jacard_coef: 0.6729
# Epoch 4/15
#  552/1044 [==============>...............] - ETA: 15s - loss: 0.9057 - accuracy: 0.8583 - jacard_coef: 0.7100

# %%
history = history1
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc = history.history['jacard_coef']
val_acc = history.history['val_jacard_coef']

plt.plot(epochs, acc, 'y', label='Training IoU')
plt.plot(epochs, val_acc, 'r', label='Validation IoU')
plt.title('Training and validation IoU')
plt.xlabel('Epochs')
plt.ylabel('IoU')
plt.legend()
plt.show()

# %%
#IOU
y_pred=model.predict(X_test)
y_pred_argmax=np.argmax(y_pred, axis=3)
y_test_argmax=np.argmax(y_test, axis=3)
# Out:
# C:\Users\numam\anaconda3\lib\site-packages\keras\engine\training_v1.py:2356: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,

# %%
#Using built in keras function for IoU
from tensorflow.keras.metrics import MeanIoU
n_classes = 6
IOU_keras = MeanIoU(num_classes=n_classes)  
IOU_keras.update_state(y_test_argmax, y_pred_argmax)
print("Mean IoU =", IOU_keras.result())
# Out:
# Mean IoU = Tensor("Identity:0", shape=(), dtype=float32)

# %%
import random
test_img_number = random.randint(0, len(X_test))
test_img = X_test[test_img_number]
ground_truth=y_test_argmax[test_img_number]
#test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)
prediction = (model.predict(test_img_input))
predicted_img=np.argmax(prediction, axis=3)[0,:,:]

# %%
plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img)
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(ground_truth)
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(predicted_img)
plt.show()

# %%
import tifffile as tiff
import os
import cv2
root_directory = '../input/hazing'
out_directory = './'
for path, subdirs, files in os.walk(root_directory):
    for file in files:
        filepath = os.path.join(path,file)
        filename = os.path.splitext(file)[0]
        img=cv2.imread(filepath)
        
        test_img_input = cv2.resize(img, (256, 256))
        single_patch_img = scaler.fit_transform(test_img_input.reshape(-1, test_img_input.shape[-1])).reshape(test_img_input.shape)
        
        test_img_input=np.expand_dims(single_patch_img, 0)
        prediction = (model.predict(test_img_input))
        predicted_img=(np.argmax(prediction, axis=3)[0,:,:])
        predicted_img=np.round(predicted_img)
        plt.imshow(predicted_img)
        
        fileout_name= os.path.join(out_directory,filename+'_predict.tif')
        cv2.imwrite(fileout_name,predicted_img)

# %%
os.getcwd()
# Out:
# 'C:\\Users\\numam'
