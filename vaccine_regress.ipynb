# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression as lr

# %%
vac=pd.read_csv('covid_vaccine_statewise.csv')

# %%
state=vac.groupby(vac['State']).sum()

# %%
x=state['18-44 Years (Doses Administered)'].sum()

# %%
y=state['45-60 Years (Doses Administered)'].sum()

# %%
vac
# Out:
#       Updated On        State  Total Doses Administered  Sessions   Sites   \
# 0         737806        India                   48276.0    3455.0   2957.0
# 1         737807        India                   58604.0    8532.0   4954.0
# 2         737808        India                   99449.0   13611.0   6583.0
# 3         737809        India                  195525.0   17855.0   7951.0
# 4         737810        India                  251280.0   25472.0  10504.0
# ...          ...          ...                       ...       ...      ...
# 7840      738102  West Bengal                       NaN       NaN      NaN
# 7841      738132  West Bengal                       NaN       NaN      NaN
# 7842      738015  West Bengal                       NaN       NaN      NaN
# 7843      738016  West Bengal                       NaN       NaN      NaN
# 7844      738017  West Bengal                       NaN       NaN      NaN
#
#       First Dose Administered  Second Dose Administered  \
# ...

# %%
state
# Out:
#                                           Updated On  \
# State
# Andaman and Nicobar Islands                156440970
# Andhra Pradesh                             156440970
# Arunachal Pradesh                          156440970
# Assam                                      156440970
# Bihar                                      156440970
# Chandigarh                                 156440970
# Chhattisgarh                               156440970
# Dadra and Nagar Haveli and Daman and Diu   156440970
# Delhi                                      157178988
# Goa                                        156440970
# Gujarat                                    156440970
# Haryana                                    156440970
# Himachal Pradesh                           156440970
# India                                      156440970
# Jammu and Kashmir                          156440970
# Jharkhand                                  156440970
# ...

# %%
state.columns
# Out:
# Index(['Updated On', 'Total Doses Administered', 'Sessions', ' Sites ',
#        'First Dose Administered', 'Second Dose Administered',
#        'Male (Doses Administered)', 'Female (Doses Administered)',
#        'Transgender (Doses Administered)', ' Covaxin (Doses Administered)',
#        'CoviShield (Doses Administered)', 'Sputnik V (Doses Administered)',
#        'AEFI', '18-44 Years (Doses Administered)',
#        '45-60 Years (Doses Administered)', '60+ Years (Doses Administered)',
#        '18-44 Years(Individuals Vaccinated)',
#        '45-60 Years(Individuals Vaccinated)',
#        '60+ Years(Individuals Vaccinated)', 'Male(Individuals Vaccinated)',
#        'Female(Individuals Vaccinated)', 'Transgender(Individuals Vaccinated)',
#        'Total Individuals Vaccinated'],
#       dtype='object')

# %%
x=state['First Dose Administered'].values+state['Second Dose Administered'].values

# %%
y=0
y=state['Updated On'].values

# %%
vac['Updated On']=pd.to_datetime(vac['Updated On'])

# %%
import datetime as dt

# %%
vac['Updated On']=vac['Updated On'].map(dt.datetime.toordinal)

# %%
y=0
y=vac['Updated On'].values

# %%
len(y)
# Out:
# 37

# %%
x
# Out:
# array([2.05444080e+07, 1.59167844e+09, 6.09372970e+07, 7.16389018e+08,
#        1.74129345e+09, 5.62968400e+07, 9.68123302e+08, 3.81894790e+07,
#        8.12558419e+08, 9.21895420e+07, 2.73206438e+09, 9.14454410e+08,
#        3.90132586e+08, 3.50217662e+10, 4.96053428e+08, 7.25794786e+08,
#        2.30051715e+09, 1.55789382e+09, 2.32630110e+07, 5.42010100e+06,
#        2.11353755e+09, 3.49724542e+09, 7.92677180e+07, 7.47826070e+07,
#        5.78714950e+07, 5.16154030e+07, 1.28393596e+09, 4.99557170e+07,
#        7.05467577e+08, 2.69274718e+09, 4.67045690e+07, 1.57920313e+09,
#        1.07847359e+09, 2.57959864e+08, 3.34284647e+09, 4.63276486e+08,
#        2.38259687e+09])

# %%
plt.scatter(y,x)
