# %%
#text="""research 4 - Indam conference is an avenue that brings together experts from academia and practitioner areas from India and abroad. The sixth biennial INDAR conference focused on the theme of architecting management scholarship in the era of disruption. The special issue focuses on publishing articles that advance our understanding of opportunities and challenges that businesses face in the era of disruption.research 4 - Indam conference is an avenue that brings together experts from academia and practitioner areas from India and abroad. The sixth biennial INDAR conference focused on the theme of architecting management scholarship in the era of disruption. The special issue focuses on publishing articles that advance our understanding of opportunities and challenges that businesses face in the era of disruption.research 4 - Indam conference is an avenue that brings together experts from academia and practitioner areas from India and abroad. The sixth biennial INDAR conference focused on the theme of architecting management scholarship in the era of disruption. The special issue focuses on publishing articles that advance our understanding of opportunities and challenges that businesses face in the era of disruption."""
#text="""##research 5 - Transf? Orma? Tion is a funds mental sh? Ift in a companies function by Esper aligning with ma? Rket? Nditions. A? Nd bands it at every level. .80 p? Er of employees are either sleepwalking or complete? Ed out."""
#lorem ipsum or approx ~ 892 words in it
text="""Lorem ipsum dolor sit amet, consectetur adipiscing elit. Aliquam in purus consequat, ultricies nulla et, semper quam. Curabitur porta auctor nisi sed luctus. Curabitur accumsan porta aliquam. Donec nec efficitur tellus. Proin ut nulla a erat sagittis suscipit ac sit amet nulla. Nunc rutrum mauris arcu, in dapibus velit convallis non. Fusce sed placerat magna. Aenean feugiat faucibus sapien, id fermentum tortor.
Pellentesque et nisl odio. Curabitur posuere quam dolor, id ullamcorper velit lacinia ac. Aenean sed diam quis elit placerat congue. Suspendisse id urna porttitor, varius quam nec, facilisis lorem. Praesent finibus eleifend ante, ac malesuada est auctor ac. Duis euismod massa lectus. Praesent enim quam, mattis eu fringilla ut, cursus nec sem. Nam justo massa, lobortis quis vulputate."""
text="""బడింది. లిగిన పిల్లలకు నట"""
def summary_on_image(text):
    b=0
    num=90
    iterate=int(len(text)/num)
    a=num
    finall=""
    inc=25
    x=0
    for i in range(iterate):
        c=text[b:a]+'\n'
        finall+=c
        b+=num
        a+=num
        x+=inc
    b-=num
    a-=num
    if b<len(finall):
        finall+=text[a:]
    from PIL import Image, ImageDraw, ImageFont
    fontsize=50
    # create an image
    out = Image.new("RGB", size = (2480 , 1748),  color=(255, 255, 255))

    # get a font
    # get a drawing context
    d = ImageDraw.Draw(out)

    #font = ImageFont.truetype("", fontsize)
    # draw multiline text
    d.multiline_text((200, 780), finall,font=fot  spacing = 50,  fill=(0, 0, 0))
    width, height = out.size
    newsize = ( int(width*2.5),int( height*2.5))
    import sys
    from PIL import Image, ImageDraw

    im=out
    draw = ImageDraw.Draw(im)
    #margin
    #top
    draw.line((50 - 15, 50) + (2450,50) , fill=128)
    #left
    draw.line((50 - 15 , 50) + (50 - 15,1700) , fill=128)
    #bottom
    draw.line((50 - 15,1700) + (2450,1700) , fill=128)
    #right
    draw.line((2450, 50) + (2450,1700) , fill=128)


    # write to stdout
    im.show()
summary_on_image(text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\PIL\ImageDraw.py in textlength(self, text, font, direction, features, language, embedded_color)
#     605         try:
# --> 606             return font.getlength(text, mode, direction, features, language)
#     607         except AttributeError:
#
# AttributeError: 'ImageFont' object has no attribute 'getlength'
#
# During handling of the above exception, another exception occurred:
#
# UnicodeEncodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19212/1911744972.py in <module>
#      55     # write to stdout
#      56     im.show()
# ---> 57 summary_on_image(text)
#
# ~\AppData\Local\Temp/ipykernel_19212/1911744972.py in summary_on_image(text)
#      34     #font = ImageFont.truetype("", fontsize)
#      35     # draw multiline text
# ...

# %%
import textwrap
#text="""Sed ut perspiciatis unde omnis iste natus error sit voluptatem accusantium doloremque laudantium, totam rem aperiam, eaque ipsa quae ab illo inventore veritatis et quasi architecto beatae vitae dicta sunt explicabo. Nemo enim ipsam voluptatem quia voluptas sit aspernatur aut odit aut fugit, sed quia consequuntur magni dolores eos qui ratione voluptatem sequi nesciunt. Neque porro quisquam est, qui"""
text="""బడింది. లిగిన పిల్లలకు నట"""

b=0
num=90
iterate=int(len(text)/num)
a=num
finall=""
inc=25
x=0
"""for i in range(iterate):
    c=text[b:a]+'\n'
    finall+=c
    b+=num
    a+=num
    x+=inc
b-=num
a-=num
lines=i
if b<len(finall):
    finall+=text[a:]"""
para = textwrap.wrap(text, width=100)
finall='\n'.join(para)
from PIL import Image, ImageDraw, ImageFont
fontsize=50
# create an image
out = Image.new("RGB", size = (2480 , 1748),  color=(255, 255, 255))

# get a font
# get a drawing context
d = ImageDraw.Draw(out)

font = ImageFont.truetype("arial.ttf", fontsize)
# draw multiline text
lines=len(para)
d.multiline_text((115, (width/2)-(145*(lines-1))), finall, font=font , spacing = 50,  fill=(0, 0, 0))
width, height = out.size

import sys
from PIL import Image, ImageDraw

im=out
draw = ImageDraw.Draw(im)
#margin
#top
draw.line((50 - 15, 50) + (2450,50) , fill=0)
#left
draw.line((50 - 15 , 50) + (50 - 15,1700) , fill=0)
#bottom
draw.line((50 - 15,1700) + (2450,1700) , fill=0)
#right
draw.line((2450, 50) + (2450,1700) , fill=0)


# write to stdout
im.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19212/1874956752.py in <module>
#      35 # draw multiline text
#      36 lines=len(para)
# ---> 37 d.multiline_text((115, (width/2)-(145*(lines-1))), finall, font=font , spacing = 50,  fill=(0, 0, 0))
#      38 width, height = out.size
#      39
#
# NameError: name 'width' is not defined

# %%
len(text)
# Out:
# 400

# %%
finall
# Out:
# 'Sed ut perspiciatis unde omnis iste natus error sit voluptatem accusantium doloremque laudantium,\ntotam rem aperiam, eaque ipsa quae ab illo inventore veritatis et quasi architecto beatae vitae\ndicta sunt explicabo. Nemo enim ipsam voluptatem quia voluptas sit aspernatur aut odit aut fugit,\nsed quia consequuntur magni dolores eos qui ratione voluptatem sequi nesciunt. Neque porro quisquam\nest, qui'

# %%
from PIL import Image, ImageDraw, ImageFont
import textwrap

#below program just shows the image
def text_on_image0(text):
    font = ImageFont.truetype("NirmalaB.ttf", 40)
    para = textwrap.wrap(text, width=100)
    finall='\n'.join(para)
    text=finall
    image_width = 2250
    im = Image.new("RGB", size = (2480 , 1748),  color=(255, 255, 255))
    d = ImageDraw.Draw(im)
    lines=len(para)
    width=2480
    y=int(width/2)-(70*(lines-1))
    #y= 10
    x = 250
    for line in text.split("\n"):
        words = line.split(" ")

        words_length = sum(d.textlength(w, font=font) for w in words)
        space_length = (image_width - words_length) / (len(words) - 1)
        x = 100
        for word in words:
            d.text((x, y), word, font=font, fill="black")
            x += d.textlength(word, font=font) + space_length
        y += 50
    #margin
    #top
    d.line((50 - 15, 50) + (2450,50) , fill=0)
    #left
    d.line((50 - 15 , 50) + (50 - 15,1700) , fill=0)
    #bottom
    d.line((50 - 15,1700) + (2450,1700) , fill=0)
    #right
    d.line((2450, 50) + (2450,1700) , fill=0)


    im.show()
    
# Below program saves the image
def text_on_image1(text):
    font = ImageFont.truetype("NirmalaB.ttf", 40)
    para = textwrap.wrap(text, width=100)
    finall='\n'.join(para)
    text=finall
    image_width = 2250
    im = Image.new("RGB", size = (2480 , 1748),  color=(255, 255, 255))
    d = ImageDraw.Draw(im)
    lines=len(para)
    width=2480
    y=int(width/2)-(70*(lines-1))
    #y= 10
    x = 250
    for line in text.split("\n"):
        words = line.split(" ")

        words_length = sum(d.textlength(w, font=font) for w in words)
        space_length = (image_width - words_length) / (len(words) - 1)
        x = 100
        for word in words:
            d.text((x, y), word, font=font, fill="black")
            x += d.textlength(word, font=font) + space_length
        y += 50
    #margin
    #top
    d.line((50 - 15, 50) + (2450,50) , fill=0)
    #left
    d.line((50 - 15 , 50) + (50 - 15,1700) , fill=0)
    #bottom
    d.line((50 - 15,1700) + (2450,1700) , fill=0)
    #right
    d.line((2450, 50) + (2450,1700) , fill=0)


    im.save("tempImg.png")
# text="Sed ut perspiciatis unde omnis iste natus error sit voluptatem accusantium doloremque laudantium, totam rem aperiam, eaque ipsa quae ab illo inventore veritatis et quasi architecto beatae vitae dicta sunt explicabo. Nemo enim ipsam voluptatem quia voluptas sit aspernatur aut odit aut fugit, sed quia consequuntur magni dolores eos qui ratione voluptatem sequi nesciunt. Neque porro quisquam est, qui dolorem ipsum quia dolor sit amet, consectetur, adipisci velit, sed quia non numquam eius modi tempora incidunt ut labore et dolore magnam aliquam quaerat voluptatem. Ut enim ad minima veniam, quis n"
text=""" 
उद्यान दस लाख एकड़ (4,000 किमी2) से अधिक क्षेत्र में फैला हुआ है और इसमें दो पर्वत श्रृंखला (रॉकी पर्वत की उप-श्रे
"""
text_on_image0(text)
