# %%
pip install tensorflow
# Out:
# ...
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# ...
#   Using cached termcolor-1.1.0.tar.gz (3.9 kB)
# ...
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# ...
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# ...
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# ...
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# ...
#   Using cached tensorboard_plugin_wit-1.8.0-py3-none-any.whl (781 kB)
# ...
#   Using cached tensorboard_data_server-0.6.1-py3-none-any.whl (2.4 kB)
# ...
#   Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# ...
#   Using cached pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# ...
#   Using cached requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# ...
#   Using cached pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# ...
#   Using cached oauthlib-3.1.1-py2.py3-none-any.whl (146 kB)
# ...
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4847 sha256=815cc887643953ca55469bc87f4091e04976a01582ce5cd9d1fd387f0be84234
# ...

# %%
import tensorflow as tf

# %%
from tensorflow.keras.layers import Dense as d
help(d)
# Out:
# Help on class Dense in module keras.layers.core.dense:
#
# class Dense(keras.engine.base_layer.Layer)
#  |  Dense(units, activation=None, use_bias=True, kernel_initializer='glorot_uniform', bias_initializer='zeros', kernel_regularizer=None, bias_regularizer=None, activity_regularizer=None, kernel_constraint=None, bias_constraint=None, **kwargs)
#  |
#  |  Just your regular densely-connected NN layer.
#  |
#  |  `Dense` implements the operation:
#  |  `output = activation(dot(input, kernel) + bias)`
#  |  where `activation` is the element-wise activation function
#  |  passed as the `activation` argument, `kernel` is a weights matrix
#  |  created by the layer, and `bias` is a bias vector created by the layer
#  |  (only applicable if `use_bias` is `True`). These are all attributes of
#  |  `Dense`.
#  |
#  |  Note: If the input to the layer has a rank greater than 2, then `Dense`
#  |  computes the dot product between the `inputs` and the `kernel` along the
# ...

# %%
model=tf.keras.models.Sequential()
model.add(tf.keras.Input(shape=(16)))
model.add(tf.keras.layers.Dense(32))
model

# %%
inputs=tf.keras.Input(shape=(10,))
x=tf.keras.layers.Dense(10)(inputs)
outputs=tf.keras.layers.Dense(1)(x)
model=tf.keras.Model(inputs,outputs)
model

# %%
help(tf.keras.layers.LSTM)
# Out:
# Help on class LSTM in module keras.layers.recurrent_v2:
#
# class LSTM(keras.layers.recurrent.DropoutRNNCellMixin, keras.layers.recurrent.LSTM)
#  |  LSTM(units, activation='tanh', recurrent_activation='sigmoid', use_bias=True, kernel_initializer='glorot_uniform', recurrent_initializer='orthogonal', bias_initializer='zeros', unit_forget_bias=True, kernel_regularizer=None, recurrent_regularizer=None, bias_regularizer=None, activity_regularizer=None, kernel_constraint=None, recurrent_constraint=None, bias_constraint=None, dropout=0.0, recurrent_dropout=0.0, return_sequences=False, return_state=False, go_backwards=False, stateful=False, time_major=False, unroll=False, **kwargs)
#  |
#  |  Long Short-Term Memory layer - Hochreiter 1997.
#  |
#  |  See [the Keras RNN API guide](https://www.tensorflow.org/guide/keras/rnn)
#  |  for details about the usage of RNN API.
#  |
#  |  Based on available runtime hardware and constraints, this layer
# ...

# %%
lstm=tf.keras.layers.LSTM(1,return_sequences=True,return_state=True)
inputs = tf.random.normal([32, 10, 8])
wso,fms,fcs=lstm(inputs)
fms.shape
# Out:
# TensorShape([32, 1])

# %%
import numpy as np
a=[i for i in range(8)]
x=np.array(a)
y=np.array([i*2 for i in a])
x=x.reshape(2,2,2)
y=y.reshape(2,2,2)
len(x.shape),x.shape
# Out:
# (3, (2, 2, 2))

# %%
x,y
# Out:
# (array([[[0, 1],
#          [2, 3]],
#
#         [[4, 5],
#          [6, 7]]]),
#  array([[[ 0,  2],
#          [ 4,  6]],
#
#         [[ 8, 10],
#          [12, 14]]]))

# %%
from tensorflow.keras.layers import LSTM 
model1=tf.keras.models.Sequential()
model1.add(LSTM((len(x)),return_sequences=False,input_shape=(None,x.shape[0])))
model1.compile(loss='mean_squared_error',optimizer='adam')

# %%
var=[[[i+j for i in range(12)] for j in range(12)]]
var=np.array(var)
var.shape
# Out:
# (1, 12, 12)

# %%
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm_1 (LSTM)               (None, 2)                 40
#
# ...
# Total params: 40
# Trainable params: 40
# Non-trainable params: 0
# _________________________________________________________________

# %%
model1.fit(x,y,epochs=1000)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 4s 4s/step - loss: 66.8497
# Epoch 2/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 66.8262
# Epoch 3/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 66.8027
# Epoch 4/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 66.7792
# Epoch 5/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 66.4955
# Epoch 6/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 66.4698
# Epoch 7/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 66.4441
# Epoch 8/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 66.4183
# Epoch 9/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 66.6619
# Epoch 10/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 66.3667
# Epoch 11/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 66.3409
# Epoch 12/1000
# ...

# %%
pre=model1.predict(x)
pre
# Out:
# array([[0.88245535, 0.8951674 ],
#        [0.9612076 , 0.9612547 ]], dtype=float32)

# %%
from tensorflow.keras.models import Sequential as Sequential
from tensorflow.keras.layers import Dense as Dense
from tensorflow.keras.layers import LSTM as LSTM
model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(None,1)))
model.add(LSTM(50,return_sequences=True))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm_2 (LSTM)               (None, None, 50)          10400
#
#  lstm_3 (LSTM)               (None, None, 50)          20200
#
#  dense_3 (Dense)             (None, None, 1)           51
#
# ...
# Total params: 30,651
# Trainable params: 30,651
# Non-trainable params: 0
# _________________________________________________________________

# %%
x=x.reshape(2,4,1)
y=y.reshape(2,4,1)
x.shape,y.shape
# Out:
# ((2, 4, 1), (2, 4, 1))

# %%
model.fit(x,y,epochs=10)
# Out:
# Epoch 1/10
# 1/1 [==============================] - 3s 3s/step - loss: 68.9610
# Epoch 2/10
# 1/1 [==============================] - 0s 7ms/step - loss: 68.1898
# Epoch 3/10
# 1/1 [==============================] - 0s 9ms/step - loss: 67.4114
# Epoch 4/10
# 1/1 [==============================] - 0s 6ms/step - loss: 66.6233
# Epoch 5/10
# 1/1 [==============================] - 0s 7ms/step - loss: 65.8224
# Epoch 6/10
# 1/1 [==============================] - 0s 7ms/step - loss: 65.0043
# Epoch 7/10
# 1/1 [==============================] - 0s 7ms/step - loss: 64.1647
# Epoch 8/10
# 1/1 [==============================] - 0s 6ms/step - loss: 63.2994
# Epoch 9/10
# 1/1 [==============================] - 0s 9ms/step - loss: 62.4044
# Epoch 10/10
# 1/1 [==============================] - 0s 8ms/step - loss: 61.4757

# %%
import keras.layers as k
len(dir(k))
# Out:
# 196

# %%
dir(k.Attention)
# Out:
# ['_TF_MODULE_IGNORED_PROPERTIES',
#  '__call__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_add_trackable',
#  '_add_trackable_child',
#  '_add_variable_with_custom_getter',
#  '_apply_scores',
#  '_autographed_call',
#  '_calculate_scores',
#  '_call_accepts_kwargs',
#  '_call_arg_was_passed',
#  '_call_fn_arg_defaults',
#  '_call_fn_arg_positions',
#  '_call_fn_args',
#  '_call_full_argspec',
#  '_cast_single_input',
#  '_checkpoint_dependencies',
#  '_clear_losses',
#  '_compute_dtype',
#  '_dedup_weights',
#  '_deferred_dependencies',
#  '_delete_tracking',
# ...

# %%
inputs=tf.keras.Input(shape=(x.size,))
model=tf.keras.Model(inputs,)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1260/1628075390.py in <module>
#       1 inputs=tf.keras.Input(shape=(x.size,))
# ----> 2 model=tf.keras.Model(inputs,y.shape)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\training\tracking\base.py in _method_wrapper(self, *args, **kwargs)
#     528     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     529     try:
# --> 530       result = method(self, *args, **kwargs)
#     531     finally:
#     532       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# ~\anaconda3\lib\site-packages\keras\engine\functional.py in __init__(self, inputs, outputs, name, trainable, **kwargs)
#     144                   for t in tf.nest.flatten(inputs)]):
#     145         inputs, outputs = functional_utils.clone_graph_nodes(inputs, outputs)
# ...
